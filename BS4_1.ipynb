# %%
import requests as req
import lxml
from bs4 import BeautifulSoup

url ="https://en.wikipedia.org/wiki/Expected_value"
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}
res = req.get(url ,headers=headers)

file = open('data.html','w')
file.write(res.text)
file.close()

# %%
soup = BeautifulSoup(open('data.html','r').read(),'lxml')

# %%
soup.p.text

# %%
for i in soup.findAll('p'):
    print(i.text)

# %%
soup.h3.nextSibling

# %%
for i in soup.findAll('p'):
    if(' be a random variable with a finite number of finite outcomes ' in i.text):
        print(i.text)

# %%
import requests as req
import lxml
from bs4 import BeautifulSoup

url ="https://www.google.com/"
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}
res = req.get(url ,headers=headers)

file = open('g.txt','w')
file.write(res.text)
file.close()
soup = BeautifulSoup(open('g.txt','r').read(),'lxml')

# %%
for i in soup.findAll('class'):
    print(i.next_sibling)
# Out:
# None
# ...
